# %%
import pandas as pd
import ast

df = pd.read_csv(r"C:\Users\Administrator\Documents\GitHub\stlf\base_data.csv")
df['Polygon'] = df['Polygon'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

df
# Out:
#       Unnamed: 0                                           Polygon  \
# 0              7  [[40, -120], [41, -120], [41, -119], [40, -119]]
# 1              8          [[40, -4], [41, -4], [41, -3], [40, -3]]
# 2              9  [[39, -114], [40, -114], [40, -113], [39, -113]]
# 3             10  [[55, -120], [56, -120], [56, -119], [55, -119]]
# 4             11          [[54, -6], [55, -6], [55, -5], [54, -5]]
# ...          ...                                               ...
# 9492       10351          [[51, 20], [52, 20], [52, 21], [51, 21]]
# 9493       10352          [[51, 18], [52, 18], [52, 19], [51, 19]]
# 9494       10353          [[48, 44], [49, 44], [49, 45], [48, 45]]
# 9495       10354          [[49, 12], [50, 12], [50, 13], [49, 13]]
# 9496       10355          [[42, 18], [43, 18], [43, 19], [42, 19]]
#
#       Overlay_sheet_ct      naId Title_short
# 0                   18  34488565     40N120W
# 1                   18  34485566     40N004W
# 2                   18  34485042     39N114W
# 3                   18  34510761     55N120W
# 4                   18  34509694     54N006W
# ...                ...       ...         ...
# 9492               130  44241395     51N020E
# 9493               162  44241080     51N018E
# 9494               141  44225172     48N044E
# 9495               136  44226920     49N012E
# 9496               226  44191726     42N018E
#
# [9497 rows x 5 columns]

# %%
df.to_csv(r"C:\Users\Administrator\Documents\GitHub\stlf\base_data.csv")
