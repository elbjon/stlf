# %%
import pandas as pd
import ast

df = pd.read_csv(r"C:\Users\Administrator\Documents\GitHub\stlf\base_data.csv")
#df['Polygon'] = df['Polygon'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

df
# Out:
#       Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0                0             0           7
# 1                1             1           8
# 2                2             2           9
# 3                3             3          10
# 4                4             4          11
# ...            ...           ...         ...
# 9492          9492          9492       10351
# 9493          9493          9493       10352
# 9494          9494          9494       10353
# 9495          9495          9495       10354
# 9496          9496          9496       10355
#
#                                                Polygon  Overlay_sheet_ct  \
# 0     [[40, -120], [41, -120], [41, -119], [40, -119]]                18
# 1             [[40, -4], [41, -4], [41, -3], [40, -3]]                18
# 2     [[39, -114], [40, -114], [40, -113], [39, -113]]                18
# 3     [[55, -120], [56, -120], [56, -119], [55, -119]]                18
# ...

# %%
df = df.drop(df.columns[:2], axis=1)
df.to_csv(r"C:\Users\Administrator\Documents\GitHub\stlf\base_data.csv", index=False)

# %%
for index, row in df.iterrows():
    #    # Convert the string representation of the list to an actual list of coordinates
        polygon_coords = row['Polygon'] 
        print(type(polygon_coords))

        if index == 5:
            break
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
df
# Out:
#                                                Polygon  Overlay_sheet_ct  \
# 0     [[40, -120], [41, -120], [41, -119], [40, -119]]                18
# 1             [[40, -4], [41, -4], [41, -3], [40, -3]]                18
# 2     [[39, -114], [40, -114], [40, -113], [39, -113]]                18
# 3     [[55, -120], [56, -120], [56, -119], [55, -119]]                18
# 4             [[54, -6], [55, -6], [55, -5], [54, -5]]                18
# ...                                                ...               ...
# 9492          [[51, 20], [52, 20], [52, 21], [51, 21]]               130
# 9493          [[51, 18], [52, 18], [52, 19], [51, 19]]               162
# 9494          [[48, 44], [49, 44], [49, 45], [48, 45]]               141
# 9495          [[49, 12], [50, 12], [50, 13], [49, 13]]               136
# 9496          [[42, 18], [43, 18], [43, 19], [42, 19]]               226
#
#           naId Title_short
# 0     34488565     40N120W
# 1     34485566     40N004W
# ...
